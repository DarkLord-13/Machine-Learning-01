# %% [markdown]
# <a href="https://colab.research.google.com/github/DarkLord-13/Machine-Learning-01/blob/main/ProcessingImageDataForDeepLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the image module
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
#loading an image through matplotlib.image module

img = mpimg.imread('/content/abc.jpg')
img1 = mpimg.imread('/content/nishant.JPG')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
img1.shape  #this will have more higher value as height and width as it has more pixel (better quality)
# Out:
# (3024, 4032, 3)

# %%
print(img)

# %%
img_plot = plt.imshow(img)
plt.show()
