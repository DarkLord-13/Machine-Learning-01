# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Structure of the YOLO required folder
# data:
#
#     1. train
#         1. images
#         2. labels
#     2. test
#         1. images
#     3. valid
#         1. images
#         2. labels

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.3/609.3 kB 6.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# Upload the best.pt before hand

# %% [markdown]
# Here I am using pre-trained model's weight (best.pt).
#
# We can use pre-trained yolo models as well, before running upload the folder in your drive -> then no need to change the path.
#
# else, change the path accordingly

# %%
from ultralytics import YOLO

model = YOLO()

model.train(data='/content/drive/MyDrive/jio1_harddisk_slot_detection/data1/data.yaml', model='/content/drive/MyDrive/jio1_harddisk_slot_detection/roboflow3/data/best.pt', epochs=200, task='detect', save_dir='/content/drive/MyDrive/jio1_harddisk_slot_detection/roboflow3')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 79.4MB/s]
# Ultralytics YOLOv8.0.160 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# this code zips the folder

'''
import shutil

input_path = '/content/runs'
output_path = '/content'

shutil.make_archive(output_path, 'zip', input_path)
'''
# Out:
# '/content.zip'

# %%
# this code copies the source folder to destination_folder

'''
source_folder = '/content/runs'
destination_folder = '/content/drive/MyDrive/jio1_harddisk_slot_detection/roboflow3/save_4'

shutil.copytree(source_folder, destination_folder)
'''
# Out:
# '/content/drive/MyDrive/jio1_harddisk_slot_detection/roboflow3/save_4'

# %% [markdown]
# # Validating the trained model

# %%
import locale

# Set UTF-8 locale
locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')
# Out:
# 'en_US.UTF-8'

# %%
# model='give the path of the best weights in runs/detect/train/weights'
# data='D:\DF\ML\ML_Projects(vs_studio)\jio1\data\data.yaml'        (path of the data folder)
# /content/runs/detect/train/weights/best.pt

#!yolo task=detect mode=val model='/content/runs/detect/train/weights/best.pt' data='/content/drive/MyDrive/jio1_harddisk_slot_detection/data/data.yaml'

model.val(data='/content/drive/MyDrive/jio1_harddisk_slot_detection/data1/data.yaml', model='/content/runs/detect/train/weights/best.pt', task='detect')
# Out:
# Ultralytics YOLOv8.0.160 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/jio1_harddisk_slot_detection/data1/valid/labels.cache... 144 images, 0 backgrounds, 0 corrupt: 100%|██████████| 144/144 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 9/9 [00:08<00:00,  1.07it/s]
#                    all        144        600      0.949      0.929      0.964      0.921
# Speed: 3.2ms preprocess, 8.3ms inference, 0.0ms loss, 4.2ms postprocess per image
# Results saved to runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7c99a834f700>
# fitness: 0.925068255066671
# ...

# %% [markdown]
# # Predicting (Testing)

# %%
# source='D:\DF\ML\ML_Projects(vs_studio)\jio1\data\test\images'        (give the path of the ../test/images folder)
model.predict(task='detect' , conf=0.9, source='/content/drive/MyDrive/jio1_harddisk_slot_detection/roboflow3/data/test/images', model='/content/drive/MyDrive/jio1_harddisk_slot_detection/roboflow3/save_1/detect/train/weights/best.pt', data='/content/drive/MyDrive/jio1_harddisk_slot_detection/roboflow3/data/data.yaml', save=True)
# Out:
# image 1/66 /content/drive/MyDrive/jio1_harddisk_slot_detection/roboflow3/data/test/images/-lens-google-com-10278-_jpg.rf.6c4f8aeb637a1a30e75f655b7653128a.jpg: 640x640 2 class_0s, 7.4ms
# image 2/66 /content/drive/MyDrive/jio1_harddisk_slot_detection/roboflow3/data/test/images/-lens-google-com-10647-_jpg.rf.85da2ce0da29418cd228b03755fde784.jpg: 640x640 1 class_0, 7.3ms
# image 3/66 /content/drive/MyDrive/jio1_harddisk_slot_detection/roboflow3/data/test/images/-lens-google-com-10902-_jpg.rf.1e67c7094e27184983cf168db05a2f98.jpg: 640x640 5 class_0s, 7.3ms
# image 4/66 /content/drive/MyDrive/jio1_harddisk_slot_detection/roboflow3/data/test/images/-lens-google-com-10902-_jpg.rf.7a2b30ae1e5872493664717f7bfc5eb7.jpg: 640x640 6 class_0s, 9.9ms
# image 5/66 /content/drive/MyDrive/jio1_harddisk_slot_detection/roboflow3/data/test/images/-lens-google-com-10902-_jpg.rf.bd0bc14a932808609d337c00b2907315.jpg: 640x640 2 class_0s, 7.3ms
# ...
